# %%
from jupyter_dash import JupyterDash
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from jupyter_dash import JupyterDash
#
# ModuleNotFoundError: No module named 'jupyter_dash'

# %%
# !poetry show --tree
# Out:
# dash 2.14.2 A Python framework for building reactive web-apps. Developed by Plotly.
# ├── ansi2html *
# ├── dash-core-components 2.0.0
# ├── dash-html-components 2.0.0
# ├── dash-table 5.0.0
# ├── flask >=1.0.4,<3.1
# │   ├── blinker >=1.6.2
# │   ├── click >=8.1.3
# │   │   └── colorama *
# │   ├── itsdangerous >=2.1.2
# │   ├── jinja2 >=3.1.2
# │   │   └── markupsafe >=2.0
# │   └── werkzeug >=3.0.0
# │       └── markupsafe >=2.1.1 (circular dependency aborted here)
# ├── importlib-metadata *
# │   └── zipp >=0.5
# ├── nest-asyncio *
# ├── plotly >=5.0.0
# │   ├── packaging *
# │   └── tenacity >=6.2.0
# ├── requests *
# │   ├── certifi >=2017.4.17
# │   ├── charset-normalizer >=2,<4
# │   ├── idna >=2.5,<4
# │   └── urllib3 >=1.21.1,<3
# ├── retrying *
# │   └── six >=1.7.0
# ├── setuptools *
# ├── typing-extensions >=4.1.1
# └── werkzeug <3.1
#     └── markupsafe >=2.1.1
# jupyter-dash 0.4.2 Dash support for the Jupyter notebook interface
# ├── ansi2html *
# ├── dash *
# ...
